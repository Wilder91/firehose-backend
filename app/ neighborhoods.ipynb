# %%
import sqlite3
import pandas as pd

# %%
cnx = sqlite3.connect(r'../db/development.sqlite3')

# %%
cur = cnx.cursor()

# %%
df = pd.read_sql_query("SELECT * from neighborhoods", cnx)
df.sort_values(by=['population'], ascending=False)
# Out:
#       id                      name population white black_AfAm amInd_AkNa  \
# 235  236          Towanda-Grantley        988    44        866          5
# 120  121            Evergreen Lawn        988     1        967          0
# 399  400            Evergreen Lawn        988     1        967          0
# 514  515          Towanda-Grantley        988    44        866          5
# 293  294           Moravia-Walther        978   295        588          5
# ..   ...                       ...        ...   ...        ...        ...
# 147  148          Herring Run Park          0     0          0          0
# 136  137       Greenmount Cemetery          0     0          0          0
# 83    84              Carroll Park          0     0          0          0
# 17    18          Mt Pleasant Park          0     0          0          0
# 558  559  Gwynns Falls/Leakin Park          0     0          0          0
#
#     asian natHaw_Pac other_Race twoOrMore isp_Lat housing occupied unoccupied  \
# ...

# %%
df = pd.read_sql_query("SELECT * from permits", cnx)
df
# Out:
#         id               address  \
# 0        1     321 E CROMWELL ST
# 1        2     321 E CROMWELL ST
# 2        3      835 S DECKER AVE
# 3        4     321 E CROMWELL ST
# 4        5          606 HYSON ST
# ...    ...                   ...
# 4999  5000        1029 W 36TH ST
# 5000  5001         2239 KIRK AVE
# 5001  5002        600 E PRATT ST
# 5002  5003  25 S CHARLES ST 1310
# 5003  5004     321 E CROMWELL ST
#
#                                             description  \
# 0     interior only modifications, no mep work, to i...
# 1     interior only modifications, no mep work, to i...
# 2     erect a 2nd floor rear addition 3 ft x 12 ft o...
# 3     interior only modifications, no mep work, to i...
# 4                  construct a two-story rear addition.
# ...                                                 ...
# 4999  install new 13r sprinkler system (40 sprinkler...
# 5000  adding a new fire alarm system to an existing ...
# ...
